# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.

# %%
data = {
    'col1': np.random.randint(0, 100, 6),
    'col2': np.random.randint(0, 100, 6),
    'col3': np.random.randint(0, 100, 6),
    'col4': np.random.randint(0, 100, 6)
}
df = pd.DataFrame(data)
df.set_index('col1', inplace=True)
display(df)



data2 = {
    'A': np.random.randint(0, 100, 3),
    'B': np.random.randint(0, 100, 3),
    'C': np.random.randint(0, 100, 3),
}
df2 = pd.DataFrame(data2)
df2.index = ['X', 'Y', 'Z']
display(df2)
print(f"Accessing the element at row 'Y' and column 'B'>> {df2['B']['Y']}")
# Out:
#       col2  col3  col4
# col1
# 41      98     3    16
# 23      45    70    93
# 2       34    42    96
# 86      44    72    49
# 72      45    93    63
# 82      15    29    55
#     A   B   C
# X  24  32  27
# Y  88  11  29
# Z   8  72  66
# Accessing the element at row 'Y' and column 'B'>> 11

# %% [markdown]
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.

# %%
data = {
    'a': np.random.randint(1, 10, 5),
    'b': np.random.randint(1, 10, 5),
    'c': np.random.randint(1, 10, 5),
}

df = pd.DataFrame(data)
print(f"orignal dataframe: \n {df}")
df["Product"] = (df['a']*df['b'])
print(f"Dataframe with the produt column: \n {df}")

# Row-wise and Column-wise sum
print(f"Row-wise sum:\n{df.sum(axis=0)}")
print(f"Column-wise sum:\n{df.sum(axis=1)}")
# Out:
# orignal dataframe:
#     a  b  c
# 0  8  9  2
# 1  7  7  8
# 2  8  6  8
# 3  2  7  8
# 4  3  1  2
# Dataframe with the produt column:
#     a  b  c  Product
# 0  8  9  2       72
# 1  7  7  8       49
# 2  8  6  8       48
# 3  2  7  8       14
# 4  3  1  2        3
# Row-wise sum:
# a           28
# b           30
# c           28
# Product    186
# dtype: int64
# Column-wise sum:
# 0    91
# 1    71
# 2    70
# 3    31
# 4     9
# dtype: int64

# %% [markdown]
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.

# %%
data = {
    'a': np.random.randint(1, 10, 5),
    'b': np.random.randint(1, 10, 5),
    'c': np.random.randint(1, 10, 5),
}

df = pd.DataFrame(data)
print(f"orignal dataframe: \n {df}")

#Introducing NaN values

df.loc[2, 'a'] = np.nan
df.loc[3, 'b'] = np.nan
df.loc[3, 'c'] = np.nan
df.loc[1, 'c'] = np.nan
print(f"Dataframe with Nans: \n{df}")
#filling NaNs with mean of respective coloumns

df['a'] = df['a'].fillna(df['a'].mean()).astype(int)
df['b'] = df['b'].fillna(df['b'].mean()).astype(int)
df['c'] = df['c'].fillna(df['c'].mean()).astype(int)



# dataframe after filling the Nans

display(df)
# Out:
# orignal dataframe:
#     a  b  c
# 0  7  4  1
# 1  1  2  4
# 2  9  7  3
# 3  1  1  6
# 4  4  7  2
# Dataframe with Nans:
#      a    b    c
# 0  7.0  4.0  1.0
# 1  1.0  2.0  NaN
# 2  NaN  7.0  3.0
# 3  1.0  NaN  NaN
# 4  4.0  7.0  2.0
#    a  b  c
# 0  7  4  1
# 1  1  2  2
# 2  3  7  3
# 3  1  5  2
# 4  4  7  2

# %% [markdown]
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.

# %%
data = {
    'Category': np.random.choice(['A', 'B', 'C'], 150),
    'Value': np.random.randint(1, 100, 150)
}

df = pd.DataFrame(data)
display(df.head())
summary= df.groupby('Category')['Value'].agg(['sum', 'mean'])


print(f"Summary statistics for each category: \n{summary}")


data2 = {
    'Product': np.random.choice(['PD1', 'PD2', 'PD3', 'PD4'], 150),
    'Category': np.random.choice(['A', 'B', 'C', 'D'], 150),
    'Sales': np.random.randint(1, 100, 150)
}
df2 = pd.DataFrame(data2)
display(df2.head())

groupby_cat = df2.groupby('Category')['Sales'].sum()
print(f"Total sales per category: \n{groupby_cat}")
# Out:
#   Category  Value
# 0        A     56
# 1        A     85
# 2        A      7
# 3        B     79
# 4        B     63
# Summary statistics for each category:
#            sum       mean
# Category
# A         2768  52.226415
# B         2793  50.781818
# C         2108  50.190476
#   Product Category  Sales
# 0     PD1        A     99
# 1     PD1        C     59
# 2     PD3        A      4
# 3     PD3        D     72
# 4     PD2        C     71
# Total sales per category:
# Category
# A    1950
# B    1810
# C    1893
# D    1874
# Name: Sales, dtype: int32

# %% [markdown]
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.

# %%
data = {
    'Category': np.random.choice(['A', 'B', 'C', 'E', 'F'], 150),
    'Value': np.random.randint(1, 100, 150)
}
data2 = {
    'Product': np.random.choice(['PD1', 'PD2', 'PD3', 'PD4'], 150),
    'Category': np.random.choice(['A', 'B', 'C', 'D', 'G'], 150),
    'Sales': np.random.randint(1, 100, 150)
}
df1 = pd.DataFrame(data)
df2 = pd.DataFrame(data2)
merged_df = pd.merge(df1, df2, on='Category', how='inner')
print(f"merged dataFrame: \n{merged_df}")

concat_df_row = pd.concat([df1, df2], axis=0)
concat_df_col = pd.concat([df1, df2], axis=1)
print(f"concat over row: \n{concat_df_row}")
print(f"concat over col: \n{concat_df_col}")
# Out:
# merged dataFrame:
#      Category  Value Product  Sales
# 0           C     53     PD1     82
# 1           C     53     PD3     87
# 2           C     53     PD4     93
# 3           C     53     PD3     30
# 4           C     53     PD4     84
# ...       ...    ...     ...    ...
# 2839        B     98     PD3     81
# 2840        B     98     PD2     52
# 2841        B     98     PD4     76
# 2842        B     98     PD2      9
# 2843        B     98     PD1      8
#
# [2844 rows x 4 columns]
# concat over row:
#     Category  Value Product  Sales
# 0          C   53.0     NaN    NaN
# 1          F   12.0     NaN    NaN
# 2          C   95.0     NaN    NaN
# 3          E   93.0     NaN    NaN
# 4          C   32.0     NaN    NaN
# ..       ...    ...     ...    ...
# 145        A    NaN     PD1   46.0
# 146        D    NaN     PD3   52.0
# 147        G    NaN     PD4   65.0
# 148        G    NaN     PD2   73.0
# 149        D    NaN     PD1   78.0
#
# [300 rows x 4 columns]
# ...

# %% [markdown]
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.

# %%
dates = pd.date_range(start='2024-01-01', periods=365, freq='D')
df = pd.DataFrame({'value':np.random.randint(1, 100, 365)}, index=dates)
print("Original DataFrame:")
display(df)

monthly_mean = df.resample('ME').mean()
print("Monthly mean DataFrame:")
display(monthly_mean)


dates = pd.date_range(start='2021-01-01', end='2021-12-31', freq='D')
df = pd.DataFrame({'value':np.random.randint(1, 100, 365)}, index=dates)
rolling_mean = df.rolling(window=7).mean()
print("Rolling mean DataFrame:")
display(rolling_mean)
# Out:
# Original DataFrame:
#             value
# 2024-01-01     48
# 2024-01-02     33
# 2024-01-03     52
# 2024-01-04     11
# 2024-01-05     31
# ...           ...
# 2024-12-26     89
# 2024-12-27     84
# 2024-12-28     16
# 2024-12-29     14
# 2024-12-30     76
#
# [365 rows x 1 columns]
# Monthly mean DataFrame:
#                 value
# 2024-01-31  39.064516
# 2024-02-29  39.103448
# 2024-03-31  56.870968
# 2024-04-30  53.466667
# 2024-05-31  53.774194
# 2024-06-30  55.033333
# 2024-07-31  47.000000
# 2024-08-31  53.806452
# 2024-09-30  51.400000
# 2024-10-31  38.870968
# 2024-11-30  53.966667
# 2024-12-31  46.666667
# Rolling mean DataFrame:
#                 value
# 2021-01-01        NaN
# 2021-01-02        NaN
# 2021-01-03        NaN
# 2021-01-04        NaN
# 2021-01-05        NaN
# ...               ...
# 2021-12-27  37.428571
# 2021-12-28  37.000000
# 2021-12-29  32.000000
# 2021-12-30  22.571429
# 2021-12-31  20.000000
#
# [365 rows x 1 columns]

# %% [markdown]
# ### Done with what one would need to practice to get familiar with the working of pandas and not mess up the logic or freak out when you don't understand the code your Ai gave you. The rest is that you can take help from the Ai but always know what you are doing and what your code is also doing.
# ## This is all for python practice.
